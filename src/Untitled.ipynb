# %%
nums = [1, 2, 3]
output = [2,4,6]

# %%
nums = [123]
result =list(map(lambda x: x*2,nums))
print(result)
# Out:
# [246]

# %%
import pandas as pd

df = pd.DataFrame({
    'SKU': ['A', 'B', 'C', 'D', 'E'],
    'Volume': [100, 80, 60, 40, 20]
})
print(df)
# Out:
#   SKU  Volume
# 0   A     100
# 1   B      80
# 2   C      60
# 3   D      40
# 4   E      20

# %%
df["percentage"] = (df["Volume"] /df["Volume"].sum())*100
print(df)
# Out:
#   SKU  Volume  percentage
# 0   A     100   33.333333
# 1   B      80   26.666667
# 2   C      60   20.000000
# 3   D      40   13.333333
# 4   E      20    6.666667

# %%
from statsmodels.tsa.stattools import adfuller

result = adfuller(data)
print(result[1])  # p-value
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[17], line 3
#       1 from statsmodels.tsa.stattools import adfuller
# ----> 3 result = adfuller(data)
#       4 print(result[1])
#
# NameError: name 'data' is not defined
